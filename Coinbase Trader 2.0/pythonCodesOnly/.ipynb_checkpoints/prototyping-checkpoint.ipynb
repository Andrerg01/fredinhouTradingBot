# %% [markdown]
# # Prototyping and noodles

# %%
import cbpro
import pandas as pd
import pickle as pkl
import datetime
import matplotlib.pyplot as plt
import financialFunctions as ff
import coinbaseFunctions as cf
import utilityFunctions as uf
import numpy as np
import matplotlib.patches as patches
from decimal import *
import os
from os import listdir
from os.path import isfile, join
import Strategies as sg

#Makes it so a module is changed, it updates automatically on the code
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('../../../fredinhouTradingBot_Pvt/coinbase_credentials_1.pkl', 'rb') as f:
    credentials = pkl.load(f)
Client = cbpro.AuthenticatedClient(
    credentials['APIKey'],
    credentials['SecretKey'],
    credentials['passPhrase'],
    api_url = credentials['APIurl']
    )
testingDates = [[datetime.datetime.now() - datetime.timedelta(days = 3*356 + int(r)), datetime.datetime.now() - datetime.timedelta(days = 3*356 + int(r) - 60)] for r in np.random.random(size = 10)*120]

# %%
testingDates
# Out:
# [[datetime.datetime(2020, 2, 20, 16, 19, 38, 419939),
#   datetime.datetime(2020, 4, 20, 16, 19, 38, 419949)],
#  [datetime.datetime(2020, 3, 6, 16, 19, 38, 419952),
#   datetime.datetime(2020, 5, 5, 16, 19, 38, 419953)],
#  [datetime.datetime(2020, 4, 4, 16, 19, 38, 419955),
#   datetime.datetime(2020, 6, 3, 16, 19, 38, 419956)],
#  [datetime.datetime(2020, 3, 20, 16, 19, 38, 419958),
#   datetime.datetime(2020, 5, 19, 16, 19, 38, 419959)],
#  [datetime.datetime(2020, 2, 9, 16, 19, 38, 419961),
#   datetime.datetime(2020, 4, 9, 16, 19, 38, 419962)],
#  [datetime.datetime(2020, 2, 18, 16, 19, 38, 419964),
#   datetime.datetime(2020, 4, 18, 16, 19, 38, 419965)],
#  [datetime.datetime(2020, 1, 4, 16, 19, 38, 419967),
#   datetime.datetime(2020, 3, 4, 16, 19, 38, 419968)],
#  [datetime.datetime(2020, 4, 1, 16, 19, 38, 419969),
#   datetime.datetime(2020, 5, 31, 16, 19, 38, 419971)],
#  [datetime.datetime(2020, 3, 10, 16, 19, 38, 419972),
#   datetime.datetime(2020, 5, 9, 16, 19, 38, 419973)],
#  [datetime.datetime(2020, 3, 17, 16, 19, 38, 419975),
#   datetime.datetime(2020, 5, 16, 16, 19, 38, 419976)]]

# %%
cf.getData(Client, 'BTC-USD', start = testingDates[1][0], end = testingDates[1][1], granularity = 60, verbose = True, header = '')
# Out:
# All seems to be fine, gathering data from files.
#                        Close     High      Low     Open  Return      Volume
# Date
# 2020-01-12 11:08:00  8088.05  8088.05  8084.07  8084.07     NaN    5.754785
# 2020-01-12 11:09:00  8085.29  8091.18  8085.29  8089.02     NaN    1.865473
# 2020-01-12 11:10:00  8082.49  8084.09  8081.83  8084.09     NaN    2.196877
# 2020-01-12 11:11:00  8075.02  8082.49  8075.01  8082.49     NaN    6.272719
# 2020-01-12 11:12:00  8077.28  8078.64  8075.01  8075.01     NaN    1.249073
# ...                      ...      ...      ...      ...     ...         ...
# 2020-03-12 11:03:00  6146.66  6200.00  6138.73  6172.37     NaN  105.775310
# 2020-03-12 11:04:00  6113.61  6157.33  6110.37  6144.80     NaN   83.843506
# 2020-03-12 11:05:00  6084.04  6113.51  6063.18  6113.51     NaN  148.169720
# 2020-03-12 11:06:00  6097.56  6101.54  6067.60  6084.04     NaN  110.316051
# 2020-03-12 11:07:00  6100.53  6101.53  6081.78  6090.95     NaN   49.146436
#
# [86233 rows x 6 columns]

# %%
assets = ['BTC-USD','ETH-USD','USD-USD']
ws = np.repeat(1/len(assets), len(assets))
for date in testingDates:
    dataDict = {}
    for asset in assets:
        dataDict[asset] = cf.getData(Client, asset, start = date[0], end = date[1], granularity = 60, verbose = False, header = '')[date[0] + datetime.timedelta(days = 15):date[0] + datetime.timedelta(days = 15, hours = 1)]
        if 'Return' in dataDict[asset].columns:
            dataDict[asset] = dataDict[asset].drop('Return', axis = 1)
        dataDict[asset]['Return'] = dataDict[asset]['Close'].pct_change()
        dataDict[asset] = dataDict[asset].dropna()
        
    params = {}
    params['dataDict'] = dataDict.copy()
    params['lookBackTime'] = 30*24*60
    params['minimumTrade'] = 5.0
    params['currentPortfolio'] = {assets[i]:ws[i] for i in range(len(assets))}
    params['totalFunds'] = 100.0
    print("Old Best Portfolio: " + str(Strategies.maxSharpeRatio(params)[2]))
    print("New Best Portfolio: " + str(Strategies.maxLogSigRatio(params)[2]))
    print('----------------------------------------------------------------')
# Out:
# Old Best Portfolio: {'BTC-USD': 1.0, 'ETH-USD': 0.0, 'USD-USD': 0.0}
# New Best Portfolio: {'BTC-USD': 1.0, 'ETH-USD': 0.0, 'USD-USD': 0.0}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 0.2915306975258765, 'ETH-USD': 0.6280555294127702, 'USD-USD': 0.08041377306135325}
# New Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 1.0, 'USD-USD': 0.0}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 1.0, 'ETH-USD': 0.0, 'USD-USD': 0.0}
# New Best Portfolio: {'BTC-USD': 1.0, 'ETH-USD': 0.0, 'USD-USD': 0.0}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 1.0, 'ETH-USD': 0.0, 'USD-USD': 0.0}
# New Best Portfolio: {'BTC-USD': 1.0, 'ETH-USD': 0.0, 'USD-USD': 0.0}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 1.0, 'USD-USD': 0.0}
# New Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 0.4963023338721427, 'USD-USD': 0.5036976661278574}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 1.0, 'USD-USD': 0.0}
# New Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 0.0, 'USD-USD': 1.0}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 0.16606180528432166, 'ETH-USD': 0.774054535432412, 'USD-USD': 0.05988365928326632}
# New Best Portfolio: {'BTC-USD': 0.15364898520752165, 'ETH-USD': 0.7657072194468477, 'USD-USD': 0.08064379534563071}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 0.4667111494945395, 'ETH-USD': 0.3225159544371149, 'USD-USD': 0.2107728960683456}
# New Best Portfolio: {'BTC-USD': 1.0, 'ETH-USD': 0.0, 'USD-USD': 0.0}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 1.0, 'USD-USD': 0.0}
# New Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 0.0, 'USD-USD': 1.0}
# ----------------------------------------------------------------
# Old Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 1.0, 'USD-USD': 0.0}
# New Best Portfolio: {'BTC-USD': 0.0, 'ETH-USD': 1.0, 'USD-USD': 0.0}
# ----------------------------------------------------------------

# %%
testingDates[7]
# Out:
# [datetime.datetime(2020, 3, 6, 15, 50, 31, 387826),
#  datetime.datetime(2020, 5, 5, 15, 50, 31, 387827)]

# %%
dataDict
# Out:
# {'BTC-USD':                        Close     High      Low     Open  Return     Volume
#  Date
#  2020-03-21 15:51:00  6364.48  6381.70  6352.06  6374.72     NaN  90.780039
#  2020-03-21 15:52:00  6352.01  6368.26  6352.00  6364.47     NaN  40.521722
#  2020-03-21 15:53:00  6367.61  6367.89  6348.33  6352.75     NaN  13.572048
#  2020-03-21 15:54:00  6358.60  6370.00  6353.74  6367.70     NaN  20.081588
#  2020-03-21 15:55:00  6336.57  6361.93  6334.19  6358.60     NaN  32.144832
#  ...                      ...      ...      ...      ...     ...        ...
#  2020-04-20 15:46:00  6875.48  6877.04  6874.94  6874.95     NaN  11.348125
#  2020-04-20 15:47:00  6875.85  6878.27  6874.94  6877.05     NaN  12.527635
#  2020-04-20 15:48:00  6861.00  6876.24  6861.00  6875.85     NaN  18.913455
#  2020-04-20 15:49:00  6866.85  6866.85  6856.91  6861.00     NaN  13.499915
#  2020-04-20 15:50:00  6869.25  6869.63  6864.32  6865.34     NaN   6.200951
#
#  [43160 rows x 6 columns]}

# %%
test = 'BTC-USD_1490417713_1493009713_60.pkl'
test.split("_",2)
# Out:
# ['BTC-USD', '1490417713', '1493009713_60.pkl']

# %%
dataDict['BTC-USD'] = cf.getData(Client, 'BTC-USD', start = date[0], end = date[1], granularity = 60, verbose = False, header = '')
dataDict['ETH-USD'] = cf.getData(Client, 'BCH-USD', start = date[0], end = date[1], granularity = 60, verbose = False, header = '')
dataDict['ETH-USD'] = cf.getData(Client, 'ETH-USD', start = date[0], end = date[1], granularity = 60, verbose = False, header = '')
(dataDict['ETH-USD'].drop_duplicates()).index.duplicated().any()
#dataDict['BTC-USD']['Return'] = dataDict['BTC-USD']['Close'].pct_change().dropna()
#dataDict['BCH-USD']['Return'] = dataDict['BCH-USD']['Close'].pct_change().dropna()
#dataDict['ETH-USD']['Return'] = dataDict['ETH-USD']['Close'].pct_change().dropna()
# Out:
# False

# %%
xs = []
ys = []
for w1 in np.linspace(0,1,5):
    print(w1)
    for w2 in np.linspace(0,1,5):
        for w3 in np.linspace(0,1,5):
            ws = np.array([w1, w2, w3])
            ws = ws/sum(ws)
            i = 0
            port = {}
            for key in dataDict.keys():
                port[key] = ws[i]
                i += 1
            xs += [ff.portfolioVolatility(dataDict, port)]
            ys += [ff.portfolioReturn(dataDict, port)]
msrPort = ff.maximumSharpeRatio(dataDict)
msrX = ff.portfolioVolatility(dataDict, msrPort)
msrY = ff.portfolioReturn(dataDict, msrPort)
# Out:
# 0.0
# /Users/andreguimaraes/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide
# 0.25
# 0.5
# 0.75
# 1.0

# %%
#Backtracking
downloadedAssets = ['AAVE-USD', 'ADA-USD', 'ALGO-USD', 'ATOM-USD', 'BAL-USD', 'BAND-USD', 'BCH-USD', 'BNT-USD', 'BTC-USD', 'CGLD-USD', 'COMP-USD', 'DASH-USD', 'EOS-USD', 'ETC-USD', 'ETH-USD', 'FIL-USD', 'GRT-USD', 'KNC-USD', 'LINK-USD', 'LRC-USD', 'LTC-USD', 'MATIC-USD', 'MKR-USD', 'NMR-USD', 'NU-USD', 'OMG-USD', 'OXT-USD', 'REN-USD', 'REP-USD', 'SKL-USD', 'SNX-USD', 'SUSHI-USD', 'UMA-USD', 'UNI-USD','WBTC-USD', 'XLM-USD', 'XTZ-USD', 'YFI-USD', 'ZEC-USD', 'ZRX-USD']
now = datetime.datetime.now()
testingTimeInterval = [now - datetime.timedelta(days = 3*365), now - datetime.timedelta(days = 1*365)]
epochDuration = 30*24*60*60
numberOfEpochs = 10
maxTimeDelta = (testingTimeInterval[-1]-testingTimeInterval[0]).total_seconds() - 3*epochDuration
testTimes = []
intervalBetweenDataGather = 60*60
for i in range(numberOfEpochs):
    t1 = testingTimeInterval[0] + datetime.timedelta(seconds = np.random.randint(low = epochDuration,high = maxTimeDelta))
    t2 = t1 + datetime.timedelta(seconds = int(2.1*epochDuration))
    testTimes += [[t1,t2]]

# %%
fundsPerTime = {}
i = 0.
timeStart1 = datetime.datetime.now()
for times in testTimes:
    timeStart2 = datetime.datetime.now()
    pct1 = i/len(testTimes)*100.
    header1 = uf.progressBar(pct1, time0 = timeStart1) + "\n"
    fundsPerTime[str(times)] = []
    goodAssets = []
    for asset in downloadedAssets:
        if ff.availableData(asset, times[0]) and availableData(asset, times[1]):
            goodAssets += [asset]
    goodAssets = goodAssets + ['USD-USD']
    tradingFeePct = 0.005
    currentPortfolioSize = {asset:0. for asset in goodAssets}
    currentPortfolioSize['USD-USD'] = 100.
    dataDict = cf.getData(Client, goodAssets, start = times[0], end = times[1], granularity = 60, verbose = False, header = '')
    currentDate = times[0] + datetime.timedelta(seconds = epochDuration)
    while (currentDate - times[0]).total_seconds() < 2*epochDuration:
        pct2 = (currentDate - times[0]).total_seconds()/(2*epochDuration)*100.
        uf.clear()
        print(uf.progressBar(pct2, time0 = timeStart2, header = header1))
        dataDictSoFar = {}
        for key in dataDict.keys():
            dataDictSoFar[key] = dataDict[key][:currentDate]
        totalFunds = 0
        for key in currentPortfolioSize.keys():
            totalFunds += currentPortfolioSize[key]*dataDictSoFar[key]['Close'][-1]
        print(totalFunds)
        currentPortfolio = {}
        for key in currentPortfolioSize.keys():
            currentPortfolio[key] = currentPortfolioSize[key]*dataDictSoFar[key]['Close'][-1]/totalFunds
        
        params = {}
        params['dataDict'] = dataDictSoFar.copy()
        params['lookBackTime'] = 60*60*24
        params['minimumTrade'] = 5
        #The current portfolio when this was called.
        params['currentPortfolio'] = currentPortfolio
        #The total ammount of funds available (in USD)
        params['totalFunds'] = totalFunds
        buys, sells, bestPortfolio = sg.maxSharpeRatio(params)
        for key in buys.keys():
            buys[key] = buys[key]*totalFunds/(dataDictSoFar[key]['Close'][-1])
        for key in sells.keys():
            sells[key] = sells[key]*totalFunds/(dataDictSoFar[key]['Close'][-1])
        currentPortfolioSize = makeFakeTrades(buys, sells, currentPortfolioSize, dataDictSoFar, tradingFeePct)        
        currentDate += datetime.timedelta(seconds = intervalBetweenDataGather)
        fundsPerTime[str(times)] += [totalFunds]
    i += 1
# Out:
# {'[datetime.datetime(2019, 10, 23, 10, 20, 23, 596384), datetime.datetime(2019, 12, 25, 10, 20, 23, 596384)]': [100.0, 99.52224614280588, 100.2183351273771, 102.44222340142835, 102.78655910856301, 103.06351377283899, 102.34878577374855, 99.6863648664858, 100.35703628411893, 103.02161419840817, 103.51748939665, 111.50871584829277, 112.82318470755932, 109.94007566004036, 108.18477678266956, 105.86819125557297, 108.35461089215171, 108.04869805284231, 108.14725114491657, 109.53800954806772, 110.22785218899233, 108.72886642651702, 108.97704500568962, 108.92702056310168, 108.4382641699695, 108.4169490456645, 109.44970288233041, 109.00531743371165, 108.0271035530921, 107.5321872751964, 107.68952105455739, 109.58532597709339, 109.24774772535386, 109.15881862448448, 108.52944453522905, 107.60391570252327, 107.9424489590643, 108.85050975395748, 109.71609818129343, 110.61587261020146, 109.29346946809471, 107.01643582035967, 107.30210245130843, 108.12727905299857, 106.99658402191852, 106.19374692492221, 105.9098830306556, 103.91944268357979, 101.87003440517616, 105.74777308833096, 105.17696562897608, 103.99990235030347, 103.41592827659164, 104.8259074735714, 105.98084021565172, 104.60455977918507, 102.49867563690549, 105.05594990618945, 102.36505078004258, 100.11588397863487, 97.64757129853861, 96.6406099788271, 96.52932328071896, 102.07701012102012, 97.91987871417413, 102.22000693746989, 102.05946801194727, 102.20986891598024, 101.70578574376282, 104.33904199864585, 103.76504911437759, 103.829840023607, 103.48174120187103, 101.63183480343415, 102.35338028268903, 101.64988132431739, 100.88455124134667, 100.25475373325834, 100.12747840873135, 99.55921855981538, 98.879580309241, 100.54087016222874, 101.02839480820734, 100.23476493378575, 100.7741691024771, 101.29594328931502, 101.60696588269745, 100.47922624493654, 100.34703732957716, 100.52615970471126, 100.95647554927922, 99.90565466889086, 100.83995937167522, 100.50543903061185, 100.54740106875221, 98.19709183297688, 99.74257270788311, 100.22562445804358, 100.10232816989154, 98.61583612685646, 98.86707603142158, 99.53166953125229, 99.88799655653193, 100.08067978116394, 100.10810315835207, 99.6198352318907, 100.55397716170475, 99.96292755700922, 99.14103846310825, 98.63374134003374, 98.9274931337584, 99.12488840919359, 99.16574277263857, 98.13463165094907, 96.45147835011004, 97.94203530349851, 99.57309335442133, 99.35552421724859, 99.46769026223238, 100.67141667608567, 99.82377827942933, 101.71328242374605, 100.94230788879415, 100.70361437488803, 101.61744019066766, 100.177127315982, 100.03815832714965, 99.42122725044288, 99.67702364821584, 100.0249673700757, 99.66146678083918, 100.79455350397156, 101.64359355370671, 101.20155228125755, 101.18986567295461, 101.69751035951029, 101.06741662563434, 108.01005823589054, 107.66986971625418, 108.10337191826086, 107.24425846824414, 106.00448983454213, 108.20325026919747, 112.78311391837204, 112.62366135319488, 113.2327670349899, 113.0840609739128, 112.70734111247924, 112.00615407328723, 112.27364005669983, 111.78823767941711, 109.6369105352497, 109.78904882130635, 111.58872596160259, 112.49376429333138, 112.16796849501296, 110.63827638903794, 109.96984428142602, 109.1533298465641, 111.09873409840108, 109.9203315120564, 109.93698786260745, 110.74994884333557, 109.93364766459648, 109.22800621900724, 110.24283307305264, 115.14139284339797, 114.7271698006783, 113.8419061878881, 112.0296839467785, 112.12569549668144, 111.83999392961758, 111.60997539239197, 111.22600586868226, 111.56156058568533, 112.20782171161035, 112.3437241246257, 113.3353121649883, 112.30833551664988, 112.14536515073604, 111.60583171515489, 111.408073903514, 108.6355886979183, 108.47680584936384, 108.98759110855157, 108.48843740604498, 107.74743160573972, 106.78925796053224, 106.54913253020266, 106.30092641217232, 105.19832973148777, 103.42264157647429, 105.57520090153218, 105.45209356392002, 105.08472914782416, 104.46856120652032, 105.67211590037712, 105.7903763526658, 106.140251 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-735-51f0fd989c05> in <module>
#      31         #The total ammount of funds available (in USD)
#      32         params['totalFunds'] = totalFunds
# ---> 33         buys, sells, bestPortfolio = sg.maxSharpeRatio(params)
#      34         for key in buys.keys():
#      35             buys[key] = buys[key]*totalFunds/(dataDictSoFar[key]['Close'][-1])
#
# ~/Dropbox/Personal Projects/fredinhouTradingBot/Coinbase Trader 2.0/pythonCodesOnly/Strategies.py in maxSharpeRatio(params)
#      33
#      34     #msrPort = ff.maximumSharpeRatio(dataDict.copy())
# ---> 35     msrPort = ff.maximizeStatistic(Statistic, params)
#      36
#      37     msrPort = ff.nicefyPortfolio(msrPort, treshold = minimumTrade/totalFunds)
#
# ~/Dropbox/Personal Projects/fredinhouTradingBot/Coinbase Trader 2.0/pythonCodesOnly/financialFunctions.py in maximizeStatistic(Statistic, params)
#     123                        options = {'disp': False},
#     124                        constraints = (weights_sum_to_1),
# --> 125                        bounds = bounds
#     126                       )
#     127
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     606     elif meth == 'slsqp':
#     607         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 608                                constraints, callback=callback, **options)
#     609     elif meth == 'trust-constr':
#     610         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     397
#     398             # Compute objective function
# --> 399             fx = func(x)
#     400             try:
#     401                 fx = float(np.asarray(fx))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/Dropbox/Personal Projects/fredinhouTradingBot/Coinbase Trader 2.0/pythonCodesOnly/financialFunctions.py in minStatistic(weights, Statistic, params)
#     117             i += 1
#     118         params['portfolio'] = portfolio
# --> 119         return -Statistic(params)
#     120
#     121     results = minimize(minStatistic, init_guess,
#
# ~/Dropbox/Personal Projects/fredinhouTradingBot/Coinbase Trader 2.0/pythonCodesOnly/Strategies.py in Statistic(params)
#      13         dataDict = params['dataDict']
#      14         portfolio = params['portfolio']
# ---> 15         return ff.portfolioSharpeRatio(dataDict, portfolio)
#      16
#      17     #Dictionary of all the
#
# ~/Dropbox/Personal Projects/fredinhouTradingBot/Coinbase Trader 2.0/pythonCodesOnly/financialFunctions.py in portfolioSharpeRatio(dataDict, portfolio, interval, riskfree_rate)
#      91
#      92 def portfolioSharpeRatio(dataDict, portfolio, interval = 'W', riskfree_rate = 0):
# ---> 93     r = portfolioReturn(dataDict, portfolio, interval = interval)
#      94     v = portfolioVolatility(dataDict, portfolio)
#      95     return (r-riskfree_rate)/v
#
# ~/Dropbox/Personal Projects/fredinhouTradingBot/Coinbase Trader 2.0/pythonCodesOnly/financialFunctions.py in portfolioReturn(dataDict, portfolio, interval)
#      75     for key in portfolio.keys():
#      76         weights += [portfolio[key]]
# ---> 77         intReturns += [intervalizeReturns({key:dataDict[key]}, interval = interval)[key]]
#      78     weights = np.array(weights)
#      79     intReturns = np.array(intReturns)
#
# ~/Dropbox/Personal Projects/fredinhouTradingBot/Coinbase Trader 2.0/pythonCodesOnly/financialFunctions.py in intervalizeReturns(dataDict, interval)
#      47     intRets = {}
#      48     for asset in dataDict.keys():
# ---> 49         compoundedGrowth = (1+dataDict[asset]['Return']).prod()
#      50         nPeriods = len(dataDict[asset])
#      51         intRets[asset] = compoundedGrowth**(periodsPerInterval(dataDict, interval = interval)/nPeriods) - 1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11583             skipna=skipna,
#   11584             numeric_only=numeric_only,
# > 11585             min_count=min_count,
#   11586         )
#   11587
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4085                 )
#    4086             with np.errstate(all="ignore"):
# -> 4087                 return op(delegate, skipna=skipna, **kwds)
#    4088
#    4089         # TODO(EA) dispatch to Index
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      68             try:
#      69                 with np.errstate(invalid="ignore"):
# ---> 70                     return f(*args, **kwargs)
#      71             except ValueError as e:
#      72                 # we want to transform an object array
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in nanprod(values, axis, skipna, min_count, mask)
#    1108     The product of all elements on a given axis. ( NaNs are treated as 1)
#    1109     """
# -> 1110     mask = _maybe_get_mask(values, skipna, mask)
#    1111
#    1112     if skipna and mask is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _maybe_get_mask(values, skipna, mask)
#     227
#     228     if mask is None:
# --> 229         if is_bool_dtype(values.dtype) or is_integer_dtype(values.dtype):
#     230             # Boolean data cannot contain nulls, so signal via mask being None
#     231             return None
#
# KeyboardInterrupt:

# %%
dataDict['REP-USD']
# Out:
#                      Close  High   Low  Open    Return      Volume   index
# Date
# 2019-10-23 10:21:00   7.57  7.57  7.42  7.42  0.000000   52.196472  4259.0
# 2019-10-23 10:22:00   7.41  7.42  7.41  7.42 -0.021136  271.000000  4260.0
# 2019-10-23 10:23:00   7.46  7.47  7.46  7.47  0.006748   16.600000  4261.0
# 2019-10-23 10:24:00   7.45  7.45  7.45  7.45 -0.001340    7.000000  4262.0
# 2019-10-23 10:25:00   7.45  7.45  7.45  7.45  0.000000    7.200000  4263.0
# ...                    ...   ...   ...   ...       ...         ...     ...
# 2019-12-25 09:52:00   9.34  9.34  9.34  9.34  0.000000   13.656073  5412.0
# 2019-12-25 10:05:00   9.30  9.30  9.30  9.30 -0.004283    0.494108  5413.0
# 2019-12-25 10:07:00   9.34  9.34  9.34  9.34  0.004301   17.833643  5414.0
# 2019-12-25 10:10:00   9.34  9.34  9.34  9.34  0.000000    1.240255  5415.0
# 2019-12-25 10:20:00   9.28  9.28  9.28  9.28 -0.006424    4.383645  5416.0
#
# [34026 rows x 7 columns]

# %%
def makeFakeTrades(buys, sells, portfolioSize, dataDict, tradingFeePct):
    for key in sells.keys():
        if key != 'USD-USD':
            portfolioSize[key] -= sells[key]
            portfolioSize['USD-USD'] += sells[key]*dataDict[key]['Close'][-1]*(1-tradingFeePct)
            
    for key in buys.keys():
        if key != 'USD-USD':
            portfolioSize[key] += buys[key]
            portfolioSize['USD-USD'] -= buys[key]*dataDict[key]['Close'][-1]*(1-tradingFeePct)
            
    return portfolioSize

# %%
with open("../candlesDataBase/ALGO-USD/ALGO-USD_1570733820_1573325040_60.pkl", 'rb') as f:
    data = pkl.load(f)
data[testTimes[-1][0]:testTimes[-1][1]]
# Out:
#                         low    high    open   close  volume
# time
# 2019-10-24 00:58:00  0.2028  0.2028  0.2028  0.2028    1250
# 2019-10-24 01:22:00  0.2016  0.2016  0.2016  0.2016    3000
# 2019-10-24 01:35:00  0.2007  0.2007  0.2007  0.2007     291
# 2019-10-24 01:36:00  0.2006  0.2006  0.2006  0.2006    1515
# 2019-10-24 01:44:00  0.2005  0.2005  0.2005  0.2005     695
# ...                     ...     ...     ...     ...     ...
# 2019-11-09 12:34:00  0.2559  0.2559  0.2559  0.2559       1
# 2019-11-09 12:38:00  0.2561  0.2563  0.2563  0.2561      78
# 2019-11-09 12:42:00  0.2567  0.2589  0.2567  0.2589    6462
# 2019-11-09 12:43:00  0.2558  0.2559  0.2559  0.2558     618
# 2019-11-09 12:44:00  0.2558  0.2558  0.2558  0.2558      77
#
# [5831 rows x 5 columns]

# %%
print((datetime.datetime.timestamp(testTimes[-1][0]), datetime.datetime.timestamp(testTimes[-1][1])))
# Out:
# (1571896636.904792, 1577084236.904792)

# %%
data.reset_index(inplace = True)

# %%
dataff.maximumSharpeRatio(dataDict)
# Out:
# Empty DataFrame
# Columns: [Date, Low, High, Open, Close, Volume, Return]
# Index: []

# %%
with open("../candlesDataBase/ETH-USD/ETH-USD_1498231858_1500823858_60.pkl", 'rb') as f:
    print(pkl.load(f))
# Out:
#                       Close    High     Low    Open  Return      Volume
# Date
# 2017-06-23 10:31:00  328.00  328.07  328.00  328.07     NaN    7.869500
# 2017-06-23 10:32:00  328.06  328.06  328.00  328.05     NaN    7.497429
# 2017-06-23 10:33:00  328.00  328.06  328.00  328.01     NaN   33.493148
# 2017-06-23 10:34:00  328.00  328.06  328.00  328.01     NaN   19.979300
# 2017-06-23 10:35:00  328.02  328.02  328.00  328.01     NaN    9.417400
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-23 10:26:00  229.64  229.64  229.63  229.64     NaN    7.207176
# 2017-07-23 10:27:00  229.63  229.64  229.63  229.64     NaN   13.206300
# 2017-07-23 10:28:00  229.63  229.64  229.63  229.64     NaN   40.695905
# 2017-07-23 10:29:00  229.51  229.63  229.50  229.63     NaN  240.878183
# 2017-07-23 10:30:00  228.81  229.50  228.81  229.50     NaN  112.427434
#
# [42996 rows x 6 columns]

# %%
df = pd.DataFrame([[1,1],[1,2],[2,1]])
df
# Out:
#    0  1
# 0  1  1
# 1  1  2
# 2  2  1

# %%
# Out:
#                      Low  High  Open  Close  Volume
# Date
# 2019-06-03 11:07:00    1     1     1      1       0
# 2019-06-03 11:08:00    1     1     1      1       0
# 2019-06-03 11:09:00    1     1     1      1       0
# 2019-06-03 11:10:00    1     1     1      1       0
# 2019-06-03 11:11:00    1     1     1      1       0
# ...                  ...   ...   ...    ...     ...
# 2019-08-02 11:02:00    1     1     1      1       0
# 2019-08-02 11:03:00    1     1     1      1       0
# 2019-08-02 11:04:00    1     1     1      1       0
# 2019-08-02 11:05:00    1     1     1      1       0
# 2019-08-02 11:06:00    1     1     1      1       0
#
# [86400 rows x 5 columns]

# %%
#File Clean-up
downloadedAssets = ['AAVE-USD', 'ADA-USD', 'ALGO-USD', 'ATOM-USD', 'BAL-USD', 'BAND-USD', 'BCH-USD', 'BNT-USD', 'BTC-USD', 'CGLD-USD', 'COMP-USD', 'DASH-USD', 'EOS-USD', 'ETC-USD', 'ETH-USD', 'FIL-USD', 'GRT-USD', 'KNC-USD', 'LINK-USD', 'LRC-USD', 'LTC-USD', 'MATIC-USD', 'MKR-USD', 'NMR-USD', 'NU-USD', 'OMG-USD', 'OXT-USD', 'REN-USD', 'REP-USD', 'SKL-USD', 'SNX-USD', 'SUSHI-USD', 'UMA-USD', 'UNI-USD','WBTC-USD', 'XLM-USD', 'XTZ-USD', 'YFI-USD', 'ZEC-USD', 'ZRX-USD']
for asset in downloadedAssets:
    for file in listdir('../candlesDataBase/' + asset):
        if file[-3:] == 'pkl':
            with open('../candlesDataBase/' + asset + '/' + file, 'rb') as f:
                data = pkl.load(f)
            if len(data) == 0:
                print('rm ../candlesDataBase/' + asset + '/' + file)
                os.system('rm ../candlesDataBase/' + asset + '/' + file)
            else:
                print('mv ../candlesDataBase/' + asset + '/' + file + ' ../candlesDataBase/' + asset + '/' + asset + "_" + str(int(datetime.datetime.timestamp(data.index[0]))) + "_" + str(int(datetime.datetime.timestamp(data.index[-1]))) + "_" + file.split("_")[-1])
                os.system('mv ../candlesDataBase/' + asset + '/' + file + ' ../candlesDataBase/' + asset + '/' + asset + "_" + str(int(datetime.datetime.timestamp(data.index[0]))) + "_" + str(int(datetime.datetime.timestamp(data.index[-1]))) + "_" + file.split("_")[-1])
# Out:
# mv ../candlesDataBase/AAVE-USD/AAVE-USD_1612205820_1616957760_60.pkl ../candlesDataBase/AAVE-USD/AAVE-USD_1612205820_1616957760_60.pkl
# mv ../candlesDataBase/AAVE-USD/AAVE-USD_1608052380_1609613760_60.pkl ../candlesDataBase/AAVE-USD/AAVE-USD_1608052380_1609613760_60.pkl
# mv ../candlesDataBase/AAVE-USD/AAVE-USD_1609613820_1612205760_60.pkl ../candlesDataBase/AAVE-USD/AAVE-USD_1609613820_1612205760_60.pkl
# mv ../candlesDataBase/ADA-USD/ADA-USD_1616083500_1616957760_60.pkl ../candlesDataBase/ADA-USD/ADA-USD_1616083500_1616957760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1573326240_1575917040_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1573326240_1575917040_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1575918240_1578508980_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1575918240_1578508980_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1609613820_1612205760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1609613820_1612205760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1591470300_1594061460_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1591470300_1594061460_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1604429820_1607021760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1604429820_1607021760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1601837880_1604429760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1601837880_1604429760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1607021820_1609613760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1607021820_1609613760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1581101820_1583693700_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1581101820_1583693700_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1588878000_1591468380_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1588878000_1591468380_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1586285940_1588877760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1586285940_1588877760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1583693880_1586285760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1583693880_1586285760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1568141940_1570733760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1568141940_1570733760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1596653820_1599245760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1596653820_1599245760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1565884980_1568141640_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1565884980_1568141640_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1594062180_1596653760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1594062180_1596653760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1612205820_1616957760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1612205820_1616957760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1578510060_1581101760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1578510060_1581101760_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1570733820_1573325040_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1570733820_1573325040_60.pkl
# mv ../candlesDataBase/ALGO-USD/ALGO-USD_1599245820_1601837760_60.pkl ../candlesDataBase/ALGO-USD/ALGO-USD_1599245820_1601837760_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1604444700_1607036580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1604444700_1607036580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1583708700_1586300580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1583708700_1586300580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1591484760_1594076580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1591484760_1594076580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1607036640_1609628580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1607036640_1609628580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1581116640_1583708580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1581116640_1583708580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1581101820_1583693760_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1581101820_1583693760_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1596668640_1599259980_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1596668640_1599259980_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1586300700_1588892580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1586300700_1588892580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1579025760_1581101760_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1579025760_1581101760_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1601852640_1604444580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1601852640_1604444580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1579025760_1581116580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1579025760_1581116580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1599265680_1601852580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1599265680_1601852580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1594076640_1596668580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1594076640_1596668580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1583693880_1586285760_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1583693880_1586285760_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1588892640_1591484580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1588892640_1591484580_60.pkl
# mv ../candlesDataBase/ATOM-USD/ATOM-USD_1609628640_1612220580_60.pkl ../candlesDataBase/ATOM-USD/ATOM-USD_1609628640_1612220580_60.pkl
# mv ../candlesDataBase/BAL-USD/BAL-USD_1609631760_1612223700_60.pkl ../candlesDataBase/BAL-USD/BAL-USD_1609631760_1612223700_60.pkl
# mv ../candlesDataBase/BAL-USD/BAL-USD_1602000300_1604447700_60.pkl ../candlesDataBase/BAL-USD/BAL-USD_1602000300_1604447700_60.pkl
# mv ../candlesDataBase/BAL-USD/BAL-USD_1607039940_1609631700_60.pkl ../candlesDataBase/BAL-USD/BAL-USD_1607039940_1609631700_60.pkl
# mv ../candlesDataBase/BAL-USD/BAL-USD_1604448000_1607039700_60.pkl ../candlesDataBase/BAL-USD/BAL-USD_1604448000_1607039700_60.pkl
# mv ../candlesDataBase/BAL-USD/BAL-USD_1612223760_1616975640_60.pkl ../candlesDataBase/BAL-USD/BAL-USD_1612223760_1616975640_60.pkl
# mv ../candlesDataBase/BAND-USD/BAND-USD_1609631760_1612223700_60.pkl ../candlesDataBase/BAND-USD/BAND-USD_1609631760_1612223700_60.pkl
# mv ../candlesDataBase/BAND-USD/BAND-USD_1607039760_1609631700_60.pkl ../candlesDataBase/BAND-USD/BAND-USD_1607039760_1609631700_60.pkl
# mv ../candlesDataBase/BAND-USD/BAND-USD_1612223760_1616975700_60.pkl ../candlesDataBase/BAND-USD/BAND-USD_1612223760_1616975700_60.pkl
# mv ../candlesDataBase/BAND-USD/BAND-USD_1597161840_1599260040_60.pkl ../candlesDataBase/BAND-USD/BAND-USD_1597161840_1599260040_60.pkl
# mv ../candlesDataBase/BAND-USD/BAND-USD_1601855760_1604447700_60.pkl ../candlesDataBase/BAND-USD/BAND-USD_1601855760_1604447700_60.pkl
# mv ../candlesDataBase/BAND-USD/BAND-USD_1599265740_1601855700_60.pkl ../candlesDataBase/BAND-USD/BAND-USD_1599265740_1601855700_60.pkl
# mv ../candlesDataBase/BAND-USD/BAND-USD_1604447880_1607039700_60.pkl ../candlesDataBase/BAND-USD/BAND-USD_1604447880_1607039700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1560383760_1562975700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1560383760_1562975700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1539647760_1542239700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1539647760_1542239700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1521503760_1524095700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1521503760_1524095700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1557791760_1560383700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1557791760_1560383700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1513732800_1516319700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1513732800_1516319700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1607039760_1609631700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1607039760_1609631700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1573343760_1575935700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1573343760_1575935700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1531871760_1534463700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1531871760_1534463700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1526687760_1529279700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1526687760_1529279700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1544831760_1547423700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1544831760_1547423700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1612223760_1616975700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1612223760_1616975700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1583711760_1586303700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1583711760_1586303700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1524095760_1526687700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1524095760_1526687700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1529279760_1531871700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1529279760_1531871700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1552607760_1555199700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1552607760_1555199700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1588895760_1591487640_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1588895760_1591487640_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1609631760_1612223700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1609631760_1612223700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1581119760_1583711700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1581119760_1583711700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1534463760_1537055700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1534463760_1537055700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1550015760_1552607700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1550015760_1552607700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1518911760_1521503700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1518911760_1521503700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1586303760_1588895700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1586303760_1588895700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1555199760_1557791700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1555199760_1557791700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1570751760_1573343640_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1570751760_1573343640_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1537055760_1539647700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1537055760_1539647700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1596671760_1599259980_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1596671760_1599259980_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1591487760_1594079700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1591487760_1594079700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1575935760_1578527700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1575935760_1578527700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1578527760_1581119700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1578527760_1581119700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1542239760_1544831700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1542239760_1544831700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1547423760_1550015700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1547423760_1550015700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1601855760_1604447700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1601855760_1604447700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1562975760_1565567700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1562975760_1565567700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1565567760_1568159640_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1565567760_1568159640_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1568159760_1570751700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1568159760_1570751700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1604447760_1607039700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1604447760_1607039700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1516319760_1518911700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1516319760_1518911700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1594079760_1596671700_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1594079760_1596671700_60.pkl
# mv ../candlesDataBase/BCH-USD/BCH-USD_1599265680_1601855640_60.pkl ../candlesDataBase/BCH-USD/BCH-USD_1599265680_1601855640_60.pkl
# mv ../candlesDataBase/BNT-USD/BNT-USD_1609631880_1612223700_60.pkl ../candlesDataBase/BNT-USD/BNT-USD_1609631880_1612223700_60.pkl
# mv ../candlesDataBase/BNT-USD/BNT-USD_1612223760_1616975700_60.pkl ../candlesDataBase/BNT-USD/BNT-USD_1612223760_1616975700_60.pkl
# mv ../candlesDataBase/BNT-USD/BNT-USD_1608052080_1609631640_60.pkl ../candlesDataBase/BNT-USD/BNT-USD_1608052080_1609631640_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1601855760_1604447700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1601855760_1604447700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1562975760_1565567700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1562975760_1565567700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1482623760_1485215700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1482623760_1485215700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1487807760_1490399700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1487807760_1490399700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1568159760_1570751700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1568159760_1570751700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1495583760_1498175700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1495583760_1498175700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1604447760_1607039700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1604447760_1607039700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1477439760_1480031700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1477439760_1480031700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1516319760_1518911700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1516319760_1518911700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1594079760_1596671700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1594079760_1596671700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1555199760_1557791700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1555199760_1557791700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1485215820_1487807700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1485215820_1487807700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1588895760_1591487700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1588895760_1591487700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1513727760_1516319700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1513727760_1516319700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1537055760_1539647700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1537055760_1539647700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1575935760_1578527700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1575935760_1578527700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1591487760_1594079700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1591487760_1594079700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1542239760_1544831700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1542239760_1544831700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1578527760_1581119700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1578527760_1581119700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1596671760_1599260040_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1596671760_1599260040_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1474847760_1477439700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1474847760_1477439700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1547423760_1550015700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1547423760_1550015700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1498175760_1500767700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1498175760_1500767700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1461887760_1464479700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1461887760_1464479700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1529279760_1531871700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1529279760_1531871700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1464479760_1467071700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1464479760_1467071700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1500767760_1503359700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1500767760_1503359700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1492991760_1495583700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1492991760_1495583700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1552607760_1555199700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1552607760_1555199700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1511135760_1513727700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1511135760_1513727700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1570751760_1573343700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1570751760_1573343700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1503359760_1505951700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1503359760_1505951700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1581119760_1583711700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1581119760_1583711700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1609631760_1612223700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1609631760_1612223700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1508543760_1511135700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1508543760_1511135700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1534463760_1537055700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1534463760_1537055700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1550015760_1552607700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1550015760_1552607700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1469663760_1472255700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1469663760_1472255700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1518911760_1521503700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1518911760_1521503700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1505951760_1508543700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1505951760_1508543700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1467071760_1469663700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1467071760_1469663700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1586303760_1588895700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1586303760_1588895700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1480031760_1482623700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1480031760_1482623700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1560383760_1562975700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1560383760_1562975700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1539647760_1542239700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1539647760_1542239700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1521503760_1524095700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1521503760_1524095700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1565567760_1568159700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1565567760_1568159700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1557791760_1560383700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1557791760_1560383700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1607039760_1609631700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1607039760_1609631700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1459295760_1461887700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1459295760_1461887700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1573343760_1575935700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1573343760_1575935700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1472255760_1474847700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1472255760_1474847700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1531871760_1534463700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1531871760_1534463700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1490399760_1492991700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1490399760_1492991700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1544831760_1547423700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1544831760_1547423700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1526687760_1529279700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1526687760_1529279700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1612223760_1616975700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1612223760_1616975700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1599265680_1601855700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1599265680_1601855700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1583711760_1586303700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1583711760_1586303700_60.pkl
# mv ../candlesDataBase/BTC-USD/BTC-USD_1524095760_1526687700_60.pkl ../candlesDataBase/BTC-USD/BTC-USD_1524095760_1526687700_60.pkl
# mv ../candlesDataBase/CGLD-USD/CGLD-USD_1601855760_1604447700_60.pkl ../candlesDataBase/CGLD-USD/CGLD-USD_1601855760_1604447700_60.pkl
# mv ../candlesDataBase/CGLD-USD/CGLD-USD_1599265740_1601855700_60.pkl ../candlesDataBase/CGLD-USD/CGLD-USD_1599265740_1601855700_60.pkl
# mv ../candlesDataBase/CGLD-USD/CGLD-USD_1604447760_1607039700_60.pkl ../candlesDataBase/CGLD-USD/CGLD-USD_1604447760_1607039700_60.pkl
# mv ../candlesDataBase/CGLD-USD/CGLD-USD_1598976180_1599260040_60.pkl ../candlesDataBase/CGLD-USD/CGLD-USD_1598976180_1599260040_60.pkl
# mv ../candlesDataBase/CGLD-USD/CGLD-USD_1609631760_1612223700_60.pkl ../candlesDataBase/CGLD-USD/CGLD-USD_1609631760_1612223700_60.pkl
# mv ../candlesDataBase/CGLD-USD/CGLD-USD_1607039760_1609631700_60.pkl ../candlesDataBase/CGLD-USD/CGLD-USD_1607039760_1609631700_60.pkl
# mv ../candlesDataBase/CGLD-USD/CGLD-USD_1612223760_1616975700_60.pkl ../candlesDataBase/CGLD-USD/CGLD-USD_1612223760_1616975700_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1612223760_1616975700_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1612223760_1616975700_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1607039760_1609631700_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1607039760_1609631700_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1609631760_1612223700_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1609631760_1612223700_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1592929800_1594079700_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1592929800_1594079700_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1596671760_1599260040_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1596671760_1599260040_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1604447760_1607039700_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1604447760_1607039700_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1594079760_1596671700_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1594079760_1596671700_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1601855760_1604447700_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1601855760_1604447700_60.pkl
# mv ../candlesDataBase/COMP-USD/COMP-USD_1599265740_1601855700_60.pkl ../candlesDataBase/COMP-USD/COMP-USD_1599265740_1601855700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1607039760_1609631700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1607039760_1609631700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1599265680_1601855700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1599265680_1601855700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1583711760_1586303700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1583711760_1586303700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1573343760_1575935700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1573343760_1575935700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1568736900_1570751580_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1568736900_1570751580_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1588895820_1591487700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1588895820_1591487700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1596671820_1599260040_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1596671820_1599260040_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1609631760_1612223700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1609631760_1612223700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1612223880_1616975700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1612223880_1616975700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1601855820_1604447580_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1601855820_1604447580_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1570751820_1573343460_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1570751820_1573343460_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1586303820_1588895700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1586303820_1588895700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1575935760_1578527460_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1575935760_1578527460_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1581119820_1583711700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1581119820_1583711700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1578527760_1581119700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1578527760_1581119700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1594079760_1596671700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1594079760_1596671700_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1591488120_1594079640_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1591488120_1594079640_60.pkl
# mv ../candlesDataBase/DASH-USD/DASH-USD_1604447760_1607039700_60.pkl ../candlesDataBase/DASH-USD/DASH-USD_1604447760_1607039700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1560383760_1562975700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1560383760_1562975700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1565567760_1568159700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1565567760_1568159700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1607039760_1609631700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1607039760_1609631700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1604447760_1607039640_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1604447760_1607039640_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1583711760_1586303700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1583711760_1586303700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1612223760_1616975700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1612223760_1616975700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1570751820_1573343640_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1570751820_1573343640_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1581119760_1583711700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1581119760_1583711700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1578527760_1581119640_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1578527760_1581119640_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1575935820_1578527700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1575935820_1578527700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1609631760_1612223700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1609631760_1612223700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1586303760_1588895700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1586303760_1588895700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1554826320_1555199280_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1554826320_1555199280_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1601855880_1604447700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1601855880_1604447700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1588895760_1591487700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1588895760_1591487700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1591487760_1594079700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1591487760_1594079700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1596671760_1599259980_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1596671760_1599259980_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1562975760_1565567700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1562975760_1565567700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1557791820_1560383700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1557791820_1560383700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1568159760_1570751700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1568159760_1570751700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1555201020_1557791640_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1555201020_1557791640_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1573343820_1575935700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1573343820_1575935700_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1599265680_1601855640_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1599265680_1601855640_60.pkl
# mv ../candlesDataBase/EOS-USD/EOS-USD_1594079760_1596671700_60.pkl ../candlesDataBase/EOS-USD/EOS-USD_1594079760_1596671700_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1563007380_1565598720_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1563007380_1565598720_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1573375440_1575967320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1573375440_1575967320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1594111380_1596703320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1594111380_1596703320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1604479500_1607071320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1604479500_1607071320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1601887380_1604479020_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1601887380_1604479020_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1570783440_1573375320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1570783440_1573375320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1534495380_1537087260_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1534495380_1537087260_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1581151380_1583743320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1581151380_1583743320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1555231380_1557823320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1555231380_1557823320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1547455680_1550047140_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1547455680_1550047140_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1568191500_1570782720_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1568191500_1570782720_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1596703380_1599295260_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1596703380_1599295260_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1550047620_1552639260_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1550047620_1552639260_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1544863440_1547454720_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1544863440_1547454720_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1578559380_1581151320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1578559380_1581151320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1565599380_1568191200_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1565599380_1568191200_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1583743380_1586335320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1583743380_1586335320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1539679380_1542271320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1539679380_1542271320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1607071440_1609663320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1607071440_1609663320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1609663380_1612255260_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1609663380_1612255260_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1591519380_1594111320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1591519380_1594111320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1552639560_1555231260_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1552639560_1555231260_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1560415380_1563007320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1560415380_1563007320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1575967560_1578559260_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1575967560_1578559260_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1588927440_1591519320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1588927440_1591519320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1586335380_1588927320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1586335380_1588927320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1537087440_1539679080_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1537087440_1539679080_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1557823380_1560415080_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1557823380_1560415080_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1542271380_1544863320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1542271380_1544863320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1599295500_1601886600_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1599295500_1601886600_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1612255380_1617007320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1612255380_1617007320_60.pkl
# mv ../candlesDataBase/ETC-USD/ETC-USD_1533753840_1534495320_60.pkl ../candlesDataBase/ETC-USD/ETC-USD_1533753840_1534495320_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1485275520_1487867400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1485275520_1487867400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1474903920_1477495740_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1474903920_1477495740_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1537111860_1539703800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1537111860_1539703800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1480091460_1482683400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1480091460_1482683400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1516379460_1518971400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1516379460_1518971400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1547483460_1550075400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1547483460_1550075400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1539703860_1542299400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1539703860_1542299400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1607077920_1609669800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1607077920_1609669800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1599301920_1601893800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1599301920_1601893800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1506007860_1508599800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1506007860_1508599800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1544891460_1547483400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1544891460_1547483400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1563031860_1565605800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1563031860_1565605800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1534519860_1537111800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1534519860_1537111800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1493047860_1495621800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1493047860_1495621800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1487867520_1490455800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1487867520_1490455800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1513787460_1516379400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1513787460_1516379400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1521559860_1524151800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1521559860_1524151800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1555255860_1557847800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1555255860_1557847800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1511195460_1513787400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1511195460_1513787400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1482683580_1485275400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1482683580_1485275400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1550075460_1552663800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1550075460_1552663800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1495639860_1498231800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1495639860_1498231800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1581157920_1583749800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1581157920_1583749800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1529335860_1531927800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1529335860_1531927800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1500823860_1503415800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1500823860_1503415800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1526743860_1529335800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1526743860_1529335800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1575973980_1578565800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1575973980_1578565800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1464535860_1467127740_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1464535860_1467127740_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1594117920_1596709800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1594117920_1596709800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1503415860_1506007800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1503415860_1506007800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1518971460_1521559800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1518971460_1521559800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1557847860_1560439800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1557847860_1560439800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1463530440_1464533580_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1463530440_1464533580_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1591525980_1594117800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1591525980_1594117800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1469719920_1472311740_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1469719920_1472311740_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1573381920_1575973800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1573381920_1575973800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1531927860_1534519800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1531927860_1534519800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1586341920_1588933800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1586341920_1588933800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1472311860_1474903740_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1472311860_1474903740_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1588933920_1591525800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1588933920_1591525800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1604485920_1607077800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1604485920_1607077800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1498231860_1500823800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1498231860_1500823800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1552663860_1555255800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1552663860_1555255800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1601893920_1604485800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1601893920_1604485800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1542299460_1544891400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1542299460_1544891400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1524151860_1526743800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1524151860_1526743800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1583749920_1586341800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1583749920_1586341800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1467127860_1469719800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1467127860_1469719800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1477495920_1480091400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1477495920_1480091400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1490455860_1493047800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1490455860_1493047800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1568197920_1570789800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1568197920_1570789800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1612261920_1617013800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1612261920_1617013800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1609669920_1612261800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1609669920_1612261800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1570789920_1573381740_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1570789920_1573381740_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1560439860_1563031800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1560439860_1563031800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1508599860_1511195400_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1508599860_1511195400_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1596709920_1599301800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1596709920_1599301800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1565605980_1568197800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1565605980_1568197800_60.pkl
# mv ../candlesDataBase/ETH-USD/ETH-USD_1578565920_1581157800_60.pkl ../candlesDataBase/ETH-USD/ETH-USD_1578565920_1581157800_60.pkl
# mv ../candlesDataBase/FIL-USD/FIL-USD_1607533740_1609671120_60.pkl ../candlesDataBase/FIL-USD/FIL-USD_1607533740_1609671120_60.pkl
# mv ../candlesDataBase/FIL-USD/FIL-USD_1609671240_1612263120_60.pkl ../candlesDataBase/FIL-USD/FIL-USD_1609671240_1612263120_60.pkl
# mv ../candlesDataBase/FIL-USD/FIL-USD_1612263360_1617015120_60.pkl ../candlesDataBase/FIL-USD/FIL-USD_1612263360_1617015120_60.pkl
# mv ../candlesDataBase/GRT-USD/GRT-USD_1609671240_1612263120_60.pkl ../candlesDataBase/GRT-USD/GRT-USD_1609671240_1612263120_60.pkl
# mv ../candlesDataBase/GRT-USD/GRT-USD_1612263240_1617015120_60.pkl ../candlesDataBase/GRT-USD/GRT-USD_1612263240_1617015120_60.pkl
# mv ../candlesDataBase/GRT-USD/GRT-USD_1608227760_1609671120_60.pkl ../candlesDataBase/GRT-USD/GRT-USD_1608227760_1609671120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1604487240_1607079120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1604487240_1607079120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1609671600_1612263120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1609671600_1612263120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1612263300_1617015120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1612263300_1617015120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1607079300_1609671120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1607079300_1609671120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1601895420_1604487120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1601895420_1604487120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1582650840_1583751120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1582650840_1583751120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1588935240_1591527000_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1588935240_1591527000_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1594119240_1596711060_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1594119240_1596711060_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1596711240_1599303120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1596711240_1599303120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1599303240_1601895060_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1599303240_1601895060_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1586343240_1588935120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1586343240_1588935120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1583751240_1586343120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1583751240_1586343120_60.pkl
# mv ../candlesDataBase/KNC-USD/KNC-USD_1591527420_1594119120_60.pkl ../candlesDataBase/KNC-USD/KNC-USD_1591527420_1594119120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1575975240_1578567060_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1575975240_1578567060_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1581159240_1583751120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1581159240_1583751120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1609671240_1612263120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1609671240_1612263120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1596711240_1599303120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1596711240_1599303120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1568199300_1570791120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1568199300_1570791120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1612263240_1617015120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1612263240_1617015120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1599303240_1601895060_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1599303240_1601895060_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1594119240_1596711120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1594119240_1596711120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1563015240_1565607120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1563015240_1565607120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1583751300_1586343060_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1583751300_1586343060_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1565607240_1568199120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1565607240_1568199120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1586343240_1588935120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1586343240_1588935120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1607079240_1609671120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1607079240_1609671120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1591527300_1594119120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1591527300_1594119120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1573383360_1575975120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1573383360_1575975120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1604487240_1607079120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1604487240_1607079120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1601895240_1604487120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1601895240_1604487120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1588935240_1591527000_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1588935240_1591527000_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1570791240_1573383060_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1570791240_1573383060_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1578567240_1581159120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1578567240_1581159120_60.pkl
# mv ../candlesDataBase/LINK-USD/LINK-USD_1561653300_1563015120_60.pkl ../candlesDataBase/LINK-USD/LINK-USD_1561653300_1563015120_60.pkl
# mv ../candlesDataBase/LRC-USD/LRC-USD_1600185900_1601911680_60.pkl ../candlesDataBase/LRC-USD/LRC-USD_1600185900_1601911680_60.pkl
# mv ../candlesDataBase/LRC-USD/LRC-USD_1607095920_1609687680_60.pkl ../candlesDataBase/LRC-USD/LRC-USD_1607095920_1609687680_60.pkl
# mv ../candlesDataBase/LRC-USD/LRC-USD_1612279800_1617031680_60.pkl ../candlesDataBase/LRC-USD/LRC-USD_1612279800_1617031680_60.pkl
# mv ../candlesDataBase/LRC-USD/LRC-USD_1604503920_1607095680_60.pkl ../candlesDataBase/LRC-USD/LRC-USD_1604503920_1607095680_60.pkl
# mv ../candlesDataBase/LRC-USD/LRC-USD_1609687800_1612279680_60.pkl ../candlesDataBase/LRC-USD/LRC-USD_1609687800_1612279680_60.pkl
# mv ../candlesDataBase/LRC-USD/LRC-USD_1601911800_1604503680_60.pkl ../candlesDataBase/LRC-USD/LRC-USD_1601911800_1604503680_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1474921685_1477513685_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1474904160_1477495560_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1544909285_1547501285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1544887800_1547479680_60.pkl
# rm ../candlesDataBase/LTC-USD/LTC-USD_1467145685_1469737685_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1570825685_1573421285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1570807800_1573399680_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1591561685_1594153685_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1591543800_1594135620_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1477513685_1480109285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1477496220_1480086480_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1482701285_1485293285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1482679860_1485268740_60.pkl
# rm ../candlesDataBase/LTC-USD/LTC-USD_1461961685_1464553685_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1511213285_1513805285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1511191800_1513783680_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1542317285_1544909285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1542295800_1544887680_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1498249685_1500841685_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1498231800_1500823680_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1480109285_1482701285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1480091100_1482677760_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1485293285_1487885285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1485274620_1487861940_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1529353685_1531945685_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1529335800_1531927680_60.pkl
# rm ../candlesDataBase/LTC-USD/LTC-USD_1464553685_1467145685_60.pkl
# mv ../candlesDataBase/LTC-USD/LTC-USD_1601929685_1604525285_60.pkl ../candlesDataBase/LTC-USD/LTC-USD_1601911860_1604503680_60.pkl
# ...
# mv ../candlesDataBase/XTZ-USD/XTZ-USD_1568233685_1570825685_60.pkl ../candlesDataBase/XTZ-USD/XTZ-USD_1568215800_1570807620_60.pkl
# mv ../candlesDataBase/XTZ-USD/XTZ-USD_1563049685_1565641685_60.pkl ../candlesDataBase/XTZ-USD/XTZ-USD_1565108040_1565623680_60.pkl
# mv ../candlesDataBase/XTZ-USD/XTZ-USD_1586377685_1588969685_60.pkl ../candlesDataBase/XTZ-USD/XTZ-USD_1586359800_1588951680_60.pkl
# mv ../candlesDataBase/XTZ-USD/XTZ-USD_1576013285_1578605285_60.pkl ../candlesDataBase/XTZ-USD/XTZ-USD_1575991800_1578583680_60.pkl
# rm ../candlesDataBase/XTZ-USD/XTZ-USD_1506025685_1508617685_60.pkl
# rm ../candlesDataBase/XTZ-USD/XTZ-USD_1555273685_1557865685_60.pkl
# mv ../candlesDataBase/XTZ-USD/XTZ-USD_1596745685_1599337685_60.pkl ../candlesDataBase/XTZ-USD/XTZ-USD_1596727800_1599319680_60.pkl
# mv ../candlesDataBase/XTZ-USD/XTZ-USD_1612301285_1617049685_60.pkl ../candlesDataBase/XTZ-USD/XTZ-USD_1612279800_1617031680_60.pkl
# mv ../candlesDataBase/XTZ-USD/XTZ-USD_1607117285_1609709285_60.pkl ../candlesDataBase/XTZ-USD/XTZ-USD_1607095800_1609687680_60.pkl
# rm ../candlesDataBase/XTZ-USD/XTZ-USD_1526761685_1529353685_60.pkl
# rm ../candlesDataBase/XTZ-USD/XTZ-USD_1552681685_1555273685_60.pkl
# mv ../candlesDataBase/XTZ-USD/XTZ-USD_1594153685_1596745685_60.pkl ../candlesDataBase/XTZ-USD/XTZ-USD_1594135800_1596727680_60.pkl
# rm ../candlesDataBase/XTZ-USD/XTZ-USD_1513805285_1516397285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1480109285_1482701285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1529353685_1531945685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1464553685_1467145685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1485293285_1487885285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1542317285_1544909285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1498249685_1500841685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1477513685_1480109285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1482701285_1485293285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1461961685_1464553685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1511213285_1513805285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1474921685_1477513685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1544909285_1547501285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1467145685_1469737685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1591561685_1594153685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1570825685_1573421285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1547501285_1550093285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1518989285_1521577685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1493065685_1495657685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1557865685_1560457685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1550093285_1552681685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1495657685_1498249685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1573421285_1576013285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1537129685_1539721685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1588969685_1591561685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1500841685_1503433685_60.pkl
# mv ../candlesDataBase/YFI-USD/YFI-USD_1604525285_1607117285_60.pkl ../candlesDataBase/YFI-USD/YFI-USD_1604503800_1607095680_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1531945685_1534537685_60.pkl
# mv ../candlesDataBase/YFI-USD/YFI-USD_1609709285_1612301285_60.pkl ../candlesDataBase/YFI-USD/YFI-USD_1609687800_1612279680_60.pkl
# mv ../candlesDataBase/YFI-USD/YFI-USD_1601929685_1604525285_60.pkl ../candlesDataBase/YFI-USD/YFI-USD_1601911800_1604503680_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1490473685_1493065685_60.pkl
# mv ../candlesDataBase/YFI-USD/YFI-USD_1599337685_1601929685_60.pkl ../candlesDataBase/YFI-USD/YFI-USD_1600185960_1601911680_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1586377685_1588969685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1576013285_1578605285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1506025685_1508617685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1555273685_1557865685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1596745685_1599337685_60.pkl
# mv ../candlesDataBase/YFI-USD/YFI-USD_1612301285_1617049685_60.pkl ../candlesDataBase/YFI-USD/YFI-USD_1612279800_1617031680_60.pkl
# mv ../candlesDataBase/YFI-USD/YFI-USD_1607117285_1609709285_60.pkl ../candlesDataBase/YFI-USD/YFI-USD_1607095800_1609687680_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1526761685_1529353685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1552681685_1555273685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1594153685_1596745685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1513805285_1516397285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1583785685_1586377685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1487885285_1490473685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1581197285_1583785685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1565641685_1568233685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1524169685_1526761685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1459369685_1461961685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1503433685_1506025685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1516397285_1518989285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1560457685_1563049685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1578605285_1581197285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1534537685_1537129685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1472329685_1474921685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1469737685_1472329685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1539721685_1542317285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1521577685_1524169685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1568233685_1570825685_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1508617685_1511213285_60.pkl
# rm ../candlesDataBase/YFI-USD/YFI-USD_1563049685_1565641685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1550093285_1552681685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1495657685_1498249685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1573421285_1576013285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1547501285_1550093285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1518989285_1521577685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1493065685_1495657685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1557865685_1560457685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1601929685_1604525285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1490473685_1493065685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1599337685_1601929685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1588969685_1591561685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1537129685_1539721685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1604525285_1607117285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1500841685_1503433685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1531945685_1534537685_60.pkl
# mv ../candlesDataBase/ZEC-USD/ZEC-USD_1609709285_1612301285_60.pkl ../candlesDataBase/ZEC-USD/ZEC-USD_1609687800_1612279680_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1542317285_1544909285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1498249685_1500841685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1480109285_1482701285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1529353685_1531945685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1464553685_1467145685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1485293285_1487885285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1467145685_1469737685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1544909285_1547501285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1474921685_1477513685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1591561685_1594153685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1570825685_1573421285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1477513685_1480109285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1482701285_1485293285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1461961685_1464553685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1511213285_1513805285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1459369685_1461961685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1503433685_1506025685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1516397285_1518989285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1583785685_1586377685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1487885285_1490473685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1565641685_1568233685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1581197285_1583785685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1524169685_1526761685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1539721685_1542317285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1521577685_1524169685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1568233685_1570825685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1508617685_1511213285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1563049685_1565641685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1560457685_1563049685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1578605285_1581197285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1534537685_1537129685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1472329685_1474921685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1469737685_1472329685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1506025685_1508617685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1555273685_1557865685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1596745685_1599337685_60.pkl
# mv ../candlesDataBase/ZEC-USD/ZEC-USD_1612301285_1617049685_60.pkl ../candlesDataBase/ZEC-USD/ZEC-USD_1612279800_1617031680_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1586377685_1588969685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1576013285_1578605285_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1552681685_1555273685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1594153685_1596745685_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1513805285_1516397285_60.pkl
# mv ../candlesDataBase/ZEC-USD/ZEC-USD_1607117285_1609709285_60.pkl ../candlesDataBase/ZEC-USD/ZEC-USD_1607447820_1609687680_60.pkl
# rm ../candlesDataBase/ZEC-USD/ZEC-USD_1526761685_1529353685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1472329685_1474921685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1469737685_1472329685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1560457685_1563049685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1560439800_1563031680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1578605285_1581197285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1578583980_1581175680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1534537685_1537129685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1539721685_1542317285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1539703980_1542295680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1563049685_1565641685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1563031860_1565623680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1521577685_1524169685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1508617685_1511213285_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1568233685_1570825685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1568215860_1570807620_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1583785685_1586377685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1583767800_1586359680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1565641685_1568233685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1565623800_1568215680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1581197285_1583785685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1581175800_1583767680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1524169685_1526761685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1487885285_1490473685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1459369685_1461961685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1503433685_1506025685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1516397285_1518989285_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1607117285_1609709285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1607095860_1609687680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1526761685_1529353685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1513805285_1516397285_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1552681685_1555273685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1552663800_1555255680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1594153685_1596745685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1594135800_1596727680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1586377685_1588969685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1586360160_1588951680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1576013285_1578605285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1575991920_1578583680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1555273685_1557865685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1555255860_1557847680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1506025685_1508617685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1612301285_1617049685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1612279800_1617031680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1596745685_1599337685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1596727920_1599319680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1531945685_1534537685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1609709285_1612301285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1609687800_1612279680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1588969685_1591561685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1588951800_1591543620_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1537129685_1539721685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1539353280_1539703560_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1604525285_1607117285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1604503920_1607095680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1500841685_1503433685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1601929685_1604525285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1601912100_1604503560_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1599337685_1601929685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1599319800_1601911560_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1490473685_1493065685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1547501285_1550093285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1547479800_1550071680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1518989285_1521577685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1493065685_1495657685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1557865685_1560457685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1557847800_1560439680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1550093285_1552681685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1550071800_1552663680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1495657685_1498249685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1573421285_1576013285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1573399860_1575991620_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1477513685_1480109285_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1482701285_1485293285_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1511213285_1513805285_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1461961685_1464553685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1467145685_1469737685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1544909285_1547501285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1544887800_1547479680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1474921685_1477513685_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1591561685_1594153685_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1591544040_1594135680_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1570825685_1573421285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1570807800_1573399620_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1480109285_1482701285_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1464553685_1467145685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1529353685_1531945685_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1485293285_1487885285_60.pkl
# mv ../candlesDataBase/ZRX-USD/ZRX-USD_1542317285_1544909285_60.pkl ../candlesDataBase/ZRX-USD/ZRX-USD_1542295800_1544887680_60.pkl
# rm ../candlesDataBase/ZRX-USD/ZRX-USD_1498249685_1500841685_60.pkl
